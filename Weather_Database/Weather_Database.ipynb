# %%
# Import depencies

# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Get nearest cities based on Latitude/Longitude citipy module
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %%
# Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Retrieve the following information from the API call:
#  - Latitude and longitude
#  - Maximum temperature
#  - Percent humidity
#  - Percent cloudiness
#  - Wind speed
#  - Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
#        print(f"Set {set_count}")
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_curDesc = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_curDesc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | florianopolis
# Processing Record 2 of Set 1 | tera
# Processing Record 3 of Set 1 | mubi
# Processing Record 4 of Set 1 | comonfort
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | northam
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | port-gentil
# Processing Record 12 of Set 1 | ewo
# Processing Record 13 of Set 1 | buala
# Processing Record 14 of Set 1 | maketu
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | pisco
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | comodoro rivadavia
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | port augusta
# Processing Record 22 of Set 1 | talpa
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 25 of Set 1 | aksarka
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | vardo
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | verkhovazhye
# Processing Record 32 of Set 1 | iskateley
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | enugu
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | madang
# Processing Record 39 of Set 1 | muros
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | ballina
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | lima
# Processing Record 48 of Set 1 | hambantota
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | fukuma
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | kholm
# Processing Record 4 of Set 2 | tazmalt
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 2 | hit
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 2 | carbonia
# Processing Record 13 of Set 2 | lorengau
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | prudentopolis
# Processing Record 17 of Set 2 | yeppoon
# Processing Record 18 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | zhezkazgan
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | tarauaca
# Processing Record 26 of Set 2 | merrill
# Processing Record 27 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | panjab
# Processing Record 31 of Set 2 | soyo
# Processing Record 32 of Set 2 | serowe
# Processing Record 33 of Set 2 | komsomolskiy
# Processing Record 34 of Set 2 | kovernino
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | changtu
# Processing Record 37 of Set 2 | touros
# Processing Record 38 of Set 2 | port lincoln
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | awjilah
# Processing Record 42 of Set 2 | bubaque
# Processing Record 43 of Set 2 | bouca
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | santa catalina
# Processing Record 46 of Set 2 | mersing
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | ilovlya
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | punta arenas
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | tiznit
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | chulman
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | lewiston
# Processing Record 9 of Set 3 | duz
# City not found. Skipping...
# Processing Record 10 of Set 3 | strezhevoy
# Processing Record 11 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | bukama
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | lufilufi
# Processing Record 19 of Set 3 | kieta
# Processing Record 20 of Set 3 | fairbanks
# Processing Record 21 of Set 3 | mahmudia
# Processing Record 22 of Set 3 | bayir
# Processing Record 23 of Set 3 | tchollire
# Processing Record 24 of Set 3 | tuatapere
# Processing Record 25 of Set 3 | flinders
# Processing Record 26 of Set 3 | hammerfest
# Processing Record 27 of Set 3 | port macquarie
# Processing Record 28 of Set 3 | dakoro
# Processing Record 29 of Set 3 | sola
# Processing Record 30 of Set 3 | kurilsk
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | yamada
# Processing Record 33 of Set 3 | poum
# Processing Record 34 of Set 3 | kismayo
# Processing Record 35 of Set 3 | bakel
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | broken hill
# Processing Record 38 of Set 3 | changping
# Processing Record 39 of Set 3 | marystown
# Processing Record 40 of Set 3 | chama
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | pueblo
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | karratha
# Processing Record 45 of Set 3 | volkach
# Processing Record 46 of Set 3 | pavilosta
# Processing Record 47 of Set 3 | rio gallegos
# Processing Record 48 of Set 3 | goiatuba
# Processing Record 49 of Set 3 | paita
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | placido de castro
# Processing Record 3 of Set 4 | riviere-au-renard
# Processing Record 4 of Set 4 | manokwari
# Processing Record 5 of Set 4 | ginda
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | kavaratti
# Processing Record 8 of Set 4 | geraldton
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | mount isa
# Processing Record 11 of Set 4 | bitung
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | redwater
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | beringovskiy
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | bilibino
# Processing Record 18 of Set 4 | madimba
# Processing Record 19 of Set 4 | la baule-escoublac
# Processing Record 20 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 4 | arriana
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | chapais
# Processing Record 25 of Set 4 | bilma
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | ossora
# Processing Record 28 of Set 4 | parras
# City not found. Skipping...
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | westport
# Processing Record 31 of Set 4 | oranjemund
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | biu
# Processing Record 34 of Set 4 | matara
# Processing Record 35 of Set 4 | seymchan
# Processing Record 36 of Set 4 | waterloo
# Processing Record 37 of Set 4 | henties bay
# Processing Record 38 of Set 4 | abu dhabi
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | lasa
# Processing Record 41 of Set 4 | tambul
# City not found. Skipping...
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | hauterive
# Processing Record 44 of Set 4 | gambela
# Processing Record 45 of Set 4 | maceio
# Processing Record 46 of Set 4 | shalya
# Processing Record 47 of Set 4 | pangai
# Processing Record 48 of Set 4 | sinnamary
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | pangkalanbuun
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | tautira
# Processing Record 3 of Set 5 | wanlaweyn
# Processing Record 4 of Set 5 | te anau
# Processing Record 5 of Set 5 | sitka
# Processing Record 6 of Set 5 | san policarpo
# Processing Record 7 of Set 5 | mayumba
# Processing Record 8 of Set 5 | anadyr
# Processing Record 9 of Set 5 | hermanus
# Processing Record 10 of Set 5 | fallon
# Processing Record 11 of Set 5 | khurda
# Processing Record 12 of Set 5 | olot
# Processing Record 13 of Set 5 | zyryanka
# Processing Record 14 of Set 5 | tauranga
# Processing Record 15 of Set 5 | ribeira grande
# Processing Record 16 of Set 5 | nha trang
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | xapuri
# Processing Record 20 of Set 5 | codrington
# Processing Record 21 of Set 5 | humaita
# Processing Record 22 of Set 5 | longyearbyen
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | pedernales
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 27 of Set 5 | constitucion
# Processing Record 28 of Set 5 | leningradskiy
# Processing Record 29 of Set 5 | tromso
# Processing Record 30 of Set 5 | padang
# Processing Record 31 of Set 5 | poyarkovo
# Processing Record 32 of Set 5 | vestmanna
# Processing Record 33 of Set 5 | port keats
# Processing Record 34 of Set 5 | tarboro
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | nkhotakota
# Processing Record 37 of Set 5 | mogadishu
# Processing Record 38 of Set 5 | elko
# Processing Record 39 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 40 of Set 5 | brae
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | lompoc
# Processing Record 45 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 5 | cape town
# Processing Record 47 of Set 5 | singaraja
# Processing Record 48 of Set 5 | misheronskiy
# Processing Record 49 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | chuy
# Processing Record 2 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 6 | atbasar
# Processing Record 4 of Set 6 | zonguldak
# Processing Record 5 of Set 6 | nizhneangarsk
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | fairlie
# Processing Record 8 of Set 6 | sarh
# Processing Record 9 of Set 6 | gamboma
# Processing Record 10 of Set 6 | kidal
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 6 | half moon bay
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | itarema
# Processing Record 17 of Set 6 | shelabolikha
# Processing Record 18 of Set 6 | kisangani
# Processing Record 19 of Set 6 | nioro
# Processing Record 20 of Set 6 | domoni
# Processing Record 21 of Set 6 | saint anthony
# Processing Record 22 of Set 6 | olafsvik
# Processing Record 23 of Set 6 | general roca
# Processing Record 24 of Set 6 | bambous virieux
# Processing Record 25 of Set 6 | sao joao da barra
# Processing Record 26 of Set 6 | nizwa
# Processing Record 27 of Set 6 | carutapera
# Processing Record 28 of Set 6 | saint-pierre
# Processing Record 29 of Set 6 | pilar
# Processing Record 30 of Set 6 | barroquinha
# Processing Record 31 of Set 6 | krasnoselkup
# Processing Record 32 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 33 of Set 6 | calatayud
# Processing Record 34 of Set 6 | tartagal
# Processing Record 35 of Set 6 | kralendijk
# Processing Record 36 of Set 6 | cayenne
# Processing Record 37 of Set 6 | sibiti
# Processing Record 38 of Set 6 | winnemucca
# Processing Record 39 of Set 6 | coahuayana
# Processing Record 40 of Set 6 | bongandanga
# Processing Record 41 of Set 6 | clyde river
# Processing Record 42 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 6 | ghotki
# Processing Record 44 of Set 6 | plettenberg bay
# Processing Record 45 of Set 6 | alice springs
# Processing Record 46 of Set 6 | veselynove
# Processing Record 47 of Set 6 | marsabit
# Processing Record 48 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 6 | rameswaram
# Processing Record 50 of Set 6 | thinadhoo
# Processing Record 1 of Set 7 | victoria
# Processing Record 2 of Set 7 | turayf
# Processing Record 3 of Set 7 | dobryanka
# Processing Record 4 of Set 7 | lebu
# Processing Record 5 of Set 7 | kirakira
# Processing Record 6 of Set 7 | canico
# Processing Record 7 of Set 7 | ulladulla
# Processing Record 8 of Set 7 | punakha
# Processing Record 9 of Set 7 | luderitz
# Processing Record 10 of Set 7 | fort nelson
# Processing Record 11 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 7 | karpogory
# Processing Record 13 of Set 7 | iranshahr
# Processing Record 14 of Set 7 | hurghada
# Processing Record 15 of Set 7 | lincoln
# Processing Record 16 of Set 7 | atka
# City not found. Skipping...
# Processing Record 17 of Set 7 | surt
# Processing Record 18 of Set 7 | artyom
# Processing Record 19 of Set 7 | kahului
# Processing Record 20 of Set 7 | vernon
# Processing Record 21 of Set 7 | palmerston north
# Processing Record 22 of Set 7 | winfield
# Processing Record 23 of Set 7 | walvis bay
# Processing Record 24 of Set 7 | monrovia
# Processing Record 25 of Set 7 | la ronge
# Processing Record 26 of Set 7 | bethel
# Processing Record 27 of Set 7 | bonnyville
# Processing Record 28 of Set 7 | namibe
# Processing Record 29 of Set 7 | katsuura
# Processing Record 30 of Set 7 | eureka
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | sambava
# Processing Record 33 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 7 | valdivia
# Processing Record 35 of Set 7 | novopokrovka
# Processing Record 36 of Set 7 | roald
# Processing Record 37 of Set 7 | pimentel
# Processing Record 38 of Set 7 | novokayakent
# Processing Record 39 of Set 7 | jimeta
# Processing Record 40 of Set 7 | turbat
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | rognan
# Processing Record 43 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 44 of Set 7 | luau
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | kokopo
# Processing Record 47 of Set 7 | quatre cocos
# Processing Record 48 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 7 | guiyang
# Processing Record 50 of Set 7 | payo
# Processing Record 1 of Set 8 | zenzeli
# Processing Record 2 of Set 8 | kamenka
# Processing Record 3 of Set 8 | tommot
# Processing Record 4 of Set 8 | san pedro
# Processing Record 5 of Set 8 | haines junction
# Processing Record 6 of Set 8 | coquimbo
# Processing Record 7 of Set 8 | orodara
# Processing Record 8 of Set 8 | ostrovnoy
# Processing Record 9 of Set 8 | dali
# Processing Record 10 of Set 8 | bunia
# Processing Record 11 of Set 8 | kraslice
# Processing Record 12 of Set 8 | kutina
# Processing Record 13 of Set 8 | aykhal
# Processing Record 14 of Set 8 | nizhniy kuranakh
# Processing Record 15 of Set 8 | carmen de carupa
# Processing Record 16 of Set 8 | sierra vista
# Processing Record 17 of Set 8 | labuhan
# Processing Record 18 of Set 8 | vila velha
# Processing Record 19 of Set 8 | sakakah
# Processing Record 20 of Set 8 | steamboat springs
# Processing Record 21 of Set 8 | nuuk
# Processing Record 22 of Set 8 | bangkalan
# Processing Record 23 of Set 8 | korla
# Processing Record 24 of Set 8 | san pedro de macoris
# Processing Record 25 of Set 8 | avera
# Processing Record 26 of Set 8 | rumoi
# Processing Record 27 of Set 8 | saint george
# Processing Record 28 of Set 8 | karachi
# Processing Record 29 of Set 8 | yendi
# Processing Record 30 of Set 8 | aljezur
# Processing Record 31 of Set 8 | tura
# Processing Record 32 of Set 8 | swan hill
# Processing Record 33 of Set 8 | goundi
# Processing Record 34 of Set 8 | cabra
# Processing Record 35 of Set 8 | dubki
# Processing Record 36 of Set 8 | sal rei
# Processing Record 37 of Set 8 | herat
# Processing Record 38 of Set 8 | taldan
# Processing Record 39 of Set 8 | pathein
# Processing Record 40 of Set 8 | edson
# Processing Record 41 of Set 8 | ust-ishim
# Processing Record 42 of Set 8 | daru
# Processing Record 43 of Set 8 | urusha
# Processing Record 44 of Set 8 | mahina
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | yakeshi
# Processing Record 47 of Set 8 | adelanto
# Processing Record 48 of Set 8 | khandbari
# Processing Record 49 of Set 8 | nyrob
# Processing Record 50 of Set 8 | changji
# Processing Record 1 of Set 9 | katherine
# Processing Record 2 of Set 9 | narasannapeta
# Processing Record 3 of Set 9 | goure
# Processing Record 4 of Set 9 | omsukchan
# Processing Record 5 of Set 9 | saint-augustin
# Processing Record 6 of Set 9 | roma
# Processing Record 7 of Set 9 | port hedland
# Processing Record 8 of Set 9 | veraval
# Processing Record 9 of Set 9 | botou
# Processing Record 10 of Set 9 | hamilton
# Processing Record 11 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 9 | altay
# Processing Record 13 of Set 9 | lagoa
# Processing Record 14 of Set 9 | waspan
# Processing Record 15 of Set 9 | kirkwall
# Processing Record 16 of Set 9 | bengkulu
# Processing Record 17 of Set 9 | manaquiri
# Processing Record 18 of Set 9 | monterey
# Processing Record 19 of Set 9 | mackay
# Processing Record 20 of Set 9 | jieshi
# Processing Record 21 of Set 9 | kikwit
# Processing Record 22 of Set 9 | tlalchapa
# Processing Record 23 of Set 9 | nantucket
# Processing Record 24 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 9 | cabo san lucas
# Processing Record 26 of Set 9 | ubud
# Processing Record 27 of Set 9 | sawakin
# Processing Record 28 of Set 9 | kyaikto
# Processing Record 29 of Set 9 | kasongo-lunda
# Processing Record 30 of Set 9 | yokadouma
# Processing Record 31 of Set 9 | lubao
# Processing Record 32 of Set 9 | necochea
# Processing Record 33 of Set 9 | bowen
# Processing Record 34 of Set 9 | dingle
# Processing Record 35 of Set 9 | tanga
# Processing Record 36 of Set 9 | gravelbourg
# Processing Record 37 of Set 9 | erken-shakhar
# City not found. Skipping...
# Processing Record 38 of Set 9 | churapcha
# Processing Record 39 of Set 9 | shimoda
# Processing Record 40 of Set 9 | zelenoborsk
# Processing Record 41 of Set 9 | mahon
# Processing Record 42 of Set 9 | lazaro cardenas
# Processing Record 43 of Set 9 | daloa
# Processing Record 44 of Set 9 | ahuimanu
# Processing Record 45 of Set 9 | pangody
# Processing Record 46 of Set 9 | aasiaat
# Processing Record 47 of Set 9 | burnley
# Processing Record 48 of Set 9 | buraydah
# Processing Record 49 of Set 9 | assomada
# Processing Record 50 of Set 9 | ruteng
# Processing Record 1 of Set 10 | natal
# Processing Record 2 of Set 10 | bonoua
# Processing Record 3 of Set 10 | purwa
# Processing Record 4 of Set 10 | san jeronimo
# Processing Record 5 of Set 10 | nchelenge
# Processing Record 6 of Set 10 | rosetta
# Processing Record 7 of Set 10 | arlit
# Processing Record 8 of Set 10 | manjacaze
# Processing Record 9 of Set 10 | rawson
# Processing Record 10 of Set 10 | malangali
# Processing Record 11 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 12 of Set 10 | yarada
# Processing Record 13 of Set 10 | eravur
# Processing Record 14 of Set 10 | noumea
# Processing Record 15 of Set 10 | klaksvik
# Processing Record 16 of Set 10 | qui nhon
# Processing Record 17 of Set 10 | maragogi
# Processing Record 18 of Set 10 | arman
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | pionerskiy
# Processing Record 21 of Set 10 | cukai
# Processing Record 22 of Set 10 | prabumulih
# Processing Record 23 of Set 10 | zhanakorgan
# Processing Record 24 of Set 10 | lac du bonnet
# Processing Record 25 of Set 10 | ola
# Processing Record 26 of Set 10 | sao gabriel da cachoeira
# Processing Record 27 of Set 10 | zhangye
# Processing Record 28 of Set 10 | karpuninskiy
# City not found. Skipping...
# Processing Record 29 of Set 10 | sur
# Processing Record 30 of Set 10 | nyurba
# Processing Record 31 of Set 10 | shingu
# Processing Record 32 of Set 10 | katol
# Processing Record 33 of Set 10 | pacific grove
# Processing Record 34 of Set 10 | homer
# Processing Record 35 of Set 10 | taoudenni
# Processing Record 36 of Set 10 | banda aceh
# Processing Record 37 of Set 10 | alofi
# Processing Record 38 of Set 10 | meulaboh
# Processing Record 39 of Set 10 | salvador
# Processing Record 40 of Set 10 | djambala
# Processing Record 41 of Set 10 | chandbali
# Processing Record 42 of Set 10 | sao jose da coroa grande
# Processing Record 43 of Set 10 | wanning
# Processing Record 44 of Set 10 | fryanovo
# Processing Record 45 of Set 10 | nancha
# Processing Record 46 of Set 10 | gorgan
# Processing Record 47 of Set 10 | elliot
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | srednekolymsk
# Processing Record 50 of Set 10 | matelandia
# Processing Record 1 of Set 11 | aketi
# Processing Record 2 of Set 11 | brockville
# Processing Record 3 of Set 11 | moissac
# Processing Record 4 of Set 11 | pantai remis
# Processing Record 5 of Set 11 | athabasca
# Processing Record 6 of Set 11 | karagaylinskiy
# Processing Record 7 of Set 11 | mayo
# Processing Record 8 of Set 11 | hami
# Processing Record 9 of Set 11 | tugalan
# City not found. Skipping...
# Processing Record 10 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 11 of Set 11 | kitui
# Processing Record 12 of Set 11 | jardim
# Processing Record 13 of Set 11 | banjar
# Processing Record 14 of Set 11 | miri
# Processing Record 15 of Set 11 | kalmunai
# Processing Record 16 of Set 11 | poya
# Processing Record 17 of Set 11 | katihar
# Processing Record 18 of Set 11 | hobyo
# Processing Record 19 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 11 | ilog
# Processing Record 21 of Set 11 | abha
# Processing Record 22 of Set 11 | urucara
# Processing Record 23 of Set 11 | college
# Processing Record 24 of Set 11 | cururupu
# Processing Record 25 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 26 of Set 11 | kaduna
# Processing Record 27 of Set 11 | grants pass
# Processing Record 28 of Set 11 | bandarbeyla
# Processing Record 29 of Set 11 | smithers
# Processing Record 30 of Set 11 | santa maria da vitoria
# Processing Record 31 of Set 11 | celestun
# Processing Record 32 of Set 11 | kazachinskoye
# Processing Record 33 of Set 11 | elban
# Processing Record 34 of Set 11 | roswell
# Processing Record 35 of Set 11 | udachnyy
# Processing Record 36 of Set 11 | dakar
# Processing Record 37 of Set 11 | kloulklubed
# Processing Record 38 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 39 of Set 11 | anloga
# Processing Record 40 of Set 11 | shawnee
# Processing Record 41 of Set 11 | santa cruz
# Processing Record 42 of Set 11 | salalah
# Processing Record 43 of Set 11 | shenjiamen
# Processing Record 44 of Set 11 | inyonga
# Processing Record 45 of Set 11 | la gomera
# Processing Record 46 of Set 11 | pakxan
# Processing Record 47 of Set 11 | santa
# Processing Record 48 of Set 11 | kangaba
# Processing Record 49 of Set 11 | puerto escondido
# Processing Record 50 of Set 11 | nyimba
# Processing Record 1 of Set 12 | capao da canoa
# Processing Record 2 of Set 12 | egvekinot
# Processing Record 3 of Set 12 | ati
# Processing Record 4 of Set 12 | hornepayne
# Processing Record 5 of Set 12 | severo-kurilsk
# Processing Record 6 of Set 12 | ko samui
# Processing Record 7 of Set 12 | navabad
# City not found. Skipping...
# Processing Record 8 of Set 12 | manakara
# Processing Record 9 of Set 12 | inhambane
# Processing Record 10 of Set 12 | cervia
# Processing Record 11 of Set 12 | mandiana
# Processing Record 12 of Set 12 | arani
# Processing Record 13 of Set 12 | methoni
# Processing Record 14 of Set 12 | leh
# Processing Record 15 of Set 12 | gaoual
# Processing Record 16 of Set 12 | vilhena
# Processing Record 17 of Set 12 | istria
# Processing Record 18 of Set 12 | noyabrsk
# Processing Record 19 of Set 12 | lavrentiya
# Processing Record 20 of Set 12 | kudahuvadhoo
# Processing Record 21 of Set 12 | upata
# Processing Record 22 of Set 12 | suntar
# Processing Record 23 of Set 12 | valparaiso
# Processing Record 24 of Set 12 | basco
# Processing Record 25 of Set 12 | manresa
# Processing Record 26 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 27 of Set 12 | pokhara
# Processing Record 28 of Set 12 | carauari
# Processing Record 29 of Set 12 | eyl
# Processing Record 30 of Set 12 | sabha
# Processing Record 31 of Set 12 | byron bay
# Processing Record 32 of Set 12 | faya
# Processing Record 33 of Set 12 | aksha
# Processing Record 34 of Set 12 | yanam
# Processing Record 35 of Set 12 | north bend
# Processing Record 36 of Set 12 | parauna
# Processing Record 37 of Set 12 | azul
# Processing Record 38 of Set 12 | gigmoto
# Processing Record 39 of Set 12 | palmer
# Processing Record 40 of Set 12 | teguldet
# Processing Record 41 of Set 12 | michalovce
# Processing Record 42 of Set 12 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 43 of Set 12 | zarya
# Processing Record 44 of Set 12 | bonthe
# Processing Record 45 of Set 12 | shihezi
# Processing Record 46 of Set 12 | el jicaro
# Processing Record 47 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 12 | qandala
# Processing Record 49 of Set 12 | peniche
# Processing Record 50 of Set 12 | maraa
# Processing Record 1 of Set 13 | acolla
# Processing Record 2 of Set 13 | doume
# Processing Record 3 of Set 13 | ahipara
# Processing Record 4 of Set 13 | kilemary
# Processing Record 5 of Set 13 | wuwei
# Processing Record 6 of Set 13 | mabaruma
# Processing Record 7 of Set 13 | matagami
# Processing Record 8 of Set 13 | cap malheureux
# Processing Record 9 of Set 13 | okhotsk
# Processing Record 10 of Set 13 | dicabisagan
# Processing Record 11 of Set 13 | dayong
# Processing Record 12 of Set 13 | richards bay
# Processing Record 13 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 14 of Set 13 | nizhneudinsk
# Processing Record 15 of Set 13 | poronaysk
# Processing Record 16 of Set 13 | tingi
# Processing Record 17 of Set 13 | hofn
# Processing Record 18 of Set 13 | maniitsoq
# Processing Record 19 of Set 13 | kembe
# Processing Record 20 of Set 13 | grindavik
# Processing Record 21 of Set 13 | kiruna
# Processing Record 22 of Set 13 | champerico
# Processing Record 23 of Set 13 | westfield
# Processing Record 24 of Set 13 | lugovskoy
# Processing Record 25 of Set 13 | flin flon
# Processing Record 26 of Set 13 | cedar city
# Processing Record 27 of Set 13 | visby
# Processing Record 28 of Set 13 | tahoua
# Processing Record 29 of Set 13 | porto novo
# Processing Record 30 of Set 13 | khuzhir
# Processing Record 31 of Set 13 | praia
# Processing Record 32 of Set 13 | chicama
# Processing Record 33 of Set 13 | akyab
# Processing Record 34 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 13 | lanigan
# Processing Record 37 of Set 13 | abu samrah
# Processing Record 38 of Set 13 | acapulco
# Processing Record 39 of Set 13 | mlonggo
# Processing Record 40 of Set 13 | havre-saint-pierre
# Processing Record 41 of Set 13 | baykit
# Processing Record 42 of Set 13 | severo-yeniseyskiy
# Processing Record 43 of Set 13 | camargo
# Processing Record 44 of Set 13 | mackenzie
# Processing Record 45 of Set 13 | tucuman
# Processing Record 46 of Set 13 | ariquemes
# Processing Record 47 of Set 13 | tezu
# Processing Record 48 of Set 13 | kiama
# Processing Record 49 of Set 13 | viedma
# Processing Record 50 of Set 13 | mudon
# Processing Record 1 of Set 14 | ovalle
# Processing Record 2 of Set 14 | venice
# Processing Record 3 of Set 14 | kenai
# Processing Record 4 of Set 14 | pichayevo
# Processing Record 5 of Set 14 | iwaki
# Processing Record 6 of Set 14 | nador
# Processing Record 7 of Set 14 | los algarrobos
# Processing Record 8 of Set 14 | phan thiet
# Processing Record 9 of Set 14 | joao neiva
# Processing Record 10 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 14 | cascais
# Processing Record 12 of Set 14 | mayor pablo lagerenza
# Processing Record 13 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 14 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 14 | deputatskiy
# Processing Record 16 of Set 14 | laguna
# Processing Record 17 of Set 14 | rocha
# Processing Record 18 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 19 of Set 14 | kerchevskiy
# Processing Record 20 of Set 14 | manggar
# Processing Record 21 of Set 14 | santa isabel
# Processing Record 22 of Set 14 | vapi
# Processing Record 23 of Set 14 | marawi
# Processing Record 24 of Set 14 | nome
# Processing Record 25 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 14 | lubben
# Processing Record 27 of Set 14 | kedrovyy
# Processing Record 28 of Set 14 | winslow
# Processing Record 29 of Set 14 | peruibe
# Processing Record 30 of Set 14 | bokovskaya
# Processing Record 31 of Set 14 | colares
# Processing Record 32 of Set 14 | kushmurun
# Processing Record 33 of Set 14 | san angelo
# Processing Record 34 of Set 14 | polunochnoye
# Processing Record 35 of Set 14 | san quintin
# Processing Record 36 of Set 14 | buedu
# Processing Record 37 of Set 14 | jafarpur
# Processing Record 38 of Set 14 | tadine
# Processing Record 39 of Set 14 | gurupa
# Processing Record 40 of Set 14 | witu
# Processing Record 41 of Set 14 | uthal
# Processing Record 42 of Set 14 | otane
# Processing Record 43 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 14 | san jose
# Processing Record 45 of Set 14 | vanavara
# Processing Record 46 of Set 14 | pangnirtung
# Processing Record 47 of Set 14 | hovd
# Processing Record 48 of Set 14 | launceston
# Processing Record 49 of Set 14 | vyartsilya
# Processing Record 50 of Set 14 | machaneng
# Processing Record 1 of Set 15 | xinmin
# Processing Record 2 of Set 15 | namatanai
# Processing Record 3 of Set 15 | kampot
# Processing Record 4 of Set 15 | nemuro
# Processing Record 5 of Set 15 | birobidzhan
# Processing Record 6 of Set 15 | bud
# Processing Record 7 of Set 15 | dunedin
# Processing Record 8 of Set 15 | ye
# City not found. Skipping...
# Processing Record 9 of Set 15 | black river
# Processing Record 10 of Set 15 | los zacatones
# Processing Record 11 of Set 15 | hurricane
# Processing Record 12 of Set 15 | oistins
# Processing Record 13 of Set 15 | sovetskiy
# Processing Record 14 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 15 | aswan
# Processing Record 16 of Set 15 | zabaykalsk
# Processing Record 17 of Set 15 | imeni poliny osipenko
# Processing Record 18 of Set 15 | vao
# Processing Record 19 of Set 15 | uyemskiy
# Processing Record 20 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 15 | jupiter
# Processing Record 22 of Set 15 | moanda
# Processing Record 23 of Set 15 | horqueta
# Processing Record 24 of Set 15 | cockburn town
# Processing Record 25 of Set 15 | petro-slavyanka
# Processing Record 26 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 15 | nabire
# Processing Record 28 of Set 15 | nanchong
# Processing Record 29 of Set 15 | marion
# Processing Record 30 of Set 15 | batemans bay
# Processing Record 31 of Set 15 | gunjur
# Processing Record 32 of Set 15 | derzhavinsk
# Processing Record 33 of Set 15 | salym
# Processing Record 34 of Set 15 | marienburg
# Processing Record 35 of Set 15 | qaqortoq
# Processing Record 36 of Set 15 | ixtapa
# Processing Record 37 of Set 15 | macae
# Processing Record 38 of Set 15 | inuvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Florianopolis      BR -27.6146  -48.5012     71.55        83          20
# 1           Tera      NE  14.0078    0.7531     82.35        52         100
# 2           Mubi      NG  10.2676   13.2644     72.52        88         100
# 3      Comonfort      MX  20.7167 -100.7667     79.29        47         100
# 4       Thompson      CA  55.7435  -97.8558     90.88        23         100
# 5        Northam      GB  51.0333   -4.2167     68.61        68         100
# 6       Cherskiy      RU  68.7500  161.3000     48.87        59          12
# 7   Norman Wells      CA  65.2820 -126.8329     70.11        45          99
# 8     Kaitangata      NZ -46.2817  169.8464     37.11        74         100
# 9    Port-Gentil      GA  -0.7193    8.7815     73.94        81         100
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        1.74     overcast clouds
# 2        2.80          light rain
# 3        7.78     overcast clouds
# 4        2.89     overcast clouds
# 5        3.53     overcast clouds
# 6        9.60          few clouds
# 7       13.13     overcast clouds
# 8        6.02     overcast clouds
# 9       11.56     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as 
# WeatherPy_Database.csv in the Weather_Database folder

# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
